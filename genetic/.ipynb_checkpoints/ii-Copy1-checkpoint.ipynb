# %%
################### 데이터 불러오기
import numpy
import pandas as pd

"""
The y=target is to maximize this equation ASAP:
    y = w1x1+w2x2+w3x3+w4x4+w5x5+6wx6
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11,-4.7)
    What are the best values for the 6 weights w1 to w6?
    We are going to use the genetic algorithm for the best possible values after a number of generations.
"""
# data
restaurants = pd.read_csv("https://raw.githubusercontent.com/xoyeon/PDPTW/main/grubhub/0o100t100s1p100/restaurants.txt", sep = '\t')
orders = pd.read_csv("https://raw.githubusercontent.com/xoyeon/PDPTW/main/grubhub/0o100t100s1p100/orders.txt", sep = '\t')
couriers = pd.read_csv("https://raw.githubusercontent.com/xoyeon/PDPTW/main/grubhub/0o100t100s1p100/couriers.txt", sep = '\t')
rest_orders = pd.merge(restaurants, orders, how='inner', on=['restaurant'])
rest_orders.columns = ['restaurant', 'rx', 'ry', 'order', 'ox', 'oy', 'placement_time', 'ready_time']

# 주문 건
order = rest_orders[(rest_orders['placement_time']>=400) & (rest_orders['ready_time']<=700)]
print("order", order)
# 근무중인 라이더
rider = couriers[(couriers['on_time']>=400) & (couriers['off_time']<=700)]
data_len = len(rider)
print("근무중인 라이더", len(rider), "명")

delivered_num = numpy.random.uniform(low=3, high=25, size=data_len).astype(int)
dist_x = numpy.array(rider['x'])
dist_y = numpy.array(rider['y'])
on_time = numpy.array(rider['on_time'])
off_time = numpy.array(rider['off_time'])
speed = numpy.random.uniform(low=30, high=60, size=data_len).astype(int)
trustiness = numpy.full(data_len, 0.90)

new_population = numpy.stack((delivered_num, dist_x, dist_y, on_time, off_time, speed, trustiness), axis=0)
new_population
# Out:
# order     restaurant    rx    ry order     ox    oy  placement_time  ready_time
# 1           r1  8708  5633    o8   7940  6877             612         622
# 3           r1  8708  5633   o26   6992  7441             623         633
# 4           r1  8708  5633   o38  10981  6805             594         614
# 5           r1  8708  5633   o44   9254  7438             564         584
# 6           r1  8708  5633   o51   7550  6061             493         503
# ..         ...   ...   ...   ...    ...   ...             ...         ...
# 492       r105  7814  6354  o475   9203  7894             496         509
# 493       r105  7814  6354  o496   6901  6689             663         673
# 494       r106  8068  5322  o361   7210  3768             543         561
# 495       r107  8746  3178  o363   8665  3154             541         562
# 502       r114  7526  7726  o445   9454  7984             646         661
#
# [312 rows x 8 columns]
# 근무중인 라이더 53 명
# array([[1.0000e+01, 2.2000e+01, 1.0000e+01, 6.0000e+00, 7.0000e+00,
#         2.4000e+01, 3.0000e+00, 1.4000e+01, 7.0000e+00, 1.5000e+01,
#         9.0000e+00, 1.1000e+01, 4.0000e+00, 2.4000e+01, 4.0000e+00,
#         3.0000e+00, 9.0000e+00, 9.0000e+00, 2.4000e+01, 2.0000e+01,
#         3.0000e+00, 8.0000e+00, 1.3000e+01, 2.3000e+01, 1.0000e+01,
#         1.3000e+01, 8.0000e+00, 1.2000e+01, 1.2000e+01, 2.2000e+01,
#         2.1000e+01, 9.0000e+00, 1.4000e+01, 1.8000e+01, 1.4000e+01,
#         1.2000e+01, 7.0000e+00, 2.0000e+01, 1.6000e+01, 2.3000e+01,
#         1.0000e+01, 2.4000e+01, 7.0000e+00, 2.2000e+01, 8.0000e+00,
#         1.4000e+01, 1.6000e+01, 2.2000e+01, 5.0000e+00, 6.0000e+00,
#         1.7000e+01, 1.0000e+01, 1.5000e+01],
#         6.3000e+02, 6.3000e+02, 6.3000e+02, 6.3000e+02, 6.3000e+02,
#         6.3000e+02, 6.3000e+02, 6.9000e+02, 6.9000e+02, 6.9000e+02,
#         6.9000e+02, 6.9000e+02, 6.9000e+02, 6.9000e+02, 6.9000e+02,
#         6.9000e+02, 6.9000e+02, 6.9000e+02, 6.9000e+02, 6.9000e+02,
#         6.9000e+02, 6.3000e+02, 6.9000e+02, 6.9000e+02, 6.9000e+02,
#         6.9000e+02, 6.9000e+02, 6.3000e+02, 6.9000e+02, 6.3000e+02,
#         6.9000e+02, 6.9000e+02, 6.9000e+02],
#        [4.5000e+01, 3.2000e+01, 5.5000e+01, 5.2000e+01, 4.9000e+01,
#         3.9000e+01, 3.2000e+01, 3.1000e+01, 5.4000e+01, 3.7000e+01,
#         5.1000e+01, 4.8000e+01, 5.8000e+01, 5.2000e+01, 3.9000e+01,
#         5.7000e+01, 3.2000e+01, 4.9000e+01, 3.4000e+01, 4.4000e+01,
#         3.8000e+01, 3.1000e+01, 3.5000e+01, 5.8000e+01, 5.1000e+01,
#         4.0000e+01, 5.6000e+01, 5.4000e+01, 4.2000e+01, 5.3000e+01,
#         4.7000e+01, 4.1000e+01, 3.1000e+01, 3.0000e+01, 5.3000e+01,
#         4.6000e+01, 4.5000e+01, 3.1000e+01, 3.6000e+01, 5.8000e+01,
#         4.7000e+01, 3.9000e+01, 3.2000e+01, 5.2000e+01, 4.5000e+01,
#         5.7000e+01, 3.2000e+01, 3.4000e+01, 3.8000e+01, 3.4000e+01,
#         3.2000e+01, 5.5000e+01, 5.8000e+01],
#        [9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01, 9.0000e-01,
#         9.0000e-01, 9.0000e-01, 9.0000e-01]])

# %%
import pygad
import numpy

"""
Given the following function:
    y = f(w1:w6) = w1x1 + w2x2 + w3x3 + w4x4 + w5x5 + 6wx6
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11,-4.7) and y=44
What are the best values for the 6 weights (w1 to w6)? We are going to use the genetic algorithm to optimize this function.
"""
solution = solution.reshape(len(function_inputs[0]),len(function_inputs))

# Function inputs.
function_inputs = new_population # Function inputs.

desired_output = [[0],[2875],[3459],[400],[700],[50],[1]]

# desired_output = 44 # Function output.

# delivered_num, dist_x, dist_y, on_time, off_time, speed, trustiness
def fitness_func(solution, solution_idx):
    
    std = numpy.std(function_inputs[0])
    log_std = numpy.log1p(std)
    fit_std = sum(numpy.abs(log_std - desired_output[0]))
    
    speed = function_inputs[5]
    sc_speed = ((speed - min(speed)) / (max(speed) - min(speed)))
    fit_speed = sum(numpy.abs(sc_speed - desired_output[5]))
    
    trust = (function_inputs[4]- function_inputs[3]) / function_inputs[0]
    sc_trust = ((trust - min(trust)) / (max(trust) - min(trust)))
    fit_trust = sum(numpy.abs(sc_trust - desired_output[6]))
    
    # Calculating the fitness value of each solution in the current population.
    # The fitness function calulates the sum of products between each input and its corresponding weight.
#     output = numpy.sum(solution*function_inputs)
#     fitness = 1.0 / numpy.abs(output - desired_output)
    fitness = 1/fit_std + fit_speed + fit_trust
    return fitness

fitness_function = fitness_func

num_generations = 100 # Number of generations.
num_parents_mating = 7 # Number of solutions to be selected as parents in the mating pool.

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter. This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters. If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
sol_per_pop = 50 # Number of solutions in the population.
num_genes = 4

last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       on_generation=callback_generation)

# Running the GA to optimize the parameters of the function.
ga_instance.run()

# After the generations complete, some plots are showed that summarize the how the outputs/fitenss values evolve over generations.
ga_instance.plot_fitness()

# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Parameters of the best solution : {solution}".format(solution=solution))
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))

prediction = numpy.sum(numpy.array(function_inputs)*solution)
print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))

if ga_instance.best_solution_generation != -1:
    print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# Saving the GA instance.
filename = 'genetic' # The filename to which the instance is saved. The name is without extension.
ga_instance.save(filename=filename)

# Loading the saved GA instance.
loaded_ga_instance = pygad.load(filename=filename)
loaded_ga_instance.plot_fitness()
# Out:
# C:\Users\syeon\anaconda3\envs\soyeon\lib\site-packages\pygad\pygad.py:473: UserWarning: The percentage of genes to mutate (mutation_percent_genes=10) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   if not self.suppress_warnings: warnings.warn("The percentage of genes to mutate (mutation_percent_genes={mutation_percent}) resutled in selecting ({mutation_num}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.".format(mutation_percent=mutation_percent_genes, mutation_num=mutation_num_genes))
# Generation = 1
# Fitness    = 2664.323385647731
# Change     = 2664.323385647731
# Generation = 2
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 3
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 4
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 5
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 6
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 7
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 8
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 9
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 10
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 11
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 12
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 13
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 14
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 15
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 16
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 17
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 18
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 19
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 20
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 21
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 22
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 23
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 24
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 25
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 26
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 27
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 28
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 29
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 30
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 31
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 32
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 33
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 34
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 35
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 36
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 37
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 38
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 39
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 40
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 41
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 42
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 43
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 44
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 45
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 46
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 47
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 48
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 49
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 50
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 51
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 52
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 53
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 54
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 55
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 56
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 57
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 58
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 59
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 60
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 61
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 62
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 63
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 64
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 65
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 66
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 67
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 68
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 69
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 70
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 71
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 72
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 73
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 74
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 75
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 76
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 77
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 78
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 79
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 80
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 81
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 82
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 83
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 84
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 85
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 86
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 87
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 88
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 89
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 90
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 91
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 92
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 93
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 94
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 95
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 96
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 97
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 98
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 99
# Fitness    = 2664.323385647731
# Change     = 0.0
# Generation = 100
# Fitness    = 2664.323385647731
# Change     = 0.0
# Parameters of the best solution : [ 2.46277415  1.95217481 -3.33155309 -0.31593246]
# Fitness value of the best solution = 2664.323385647731
# Index of the best solution : 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14912\3588184802.py in <module>
#      78 print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))
#      79
# ---> 80 prediction = numpy.sum(numpy.array(function_inputs)*solution)
#      81 print("Predicted output based on the best solution : {prediction}".format(prediction=prediction))
#      82
#
# ValueError: operands could not be broadcast together with shapes (7,53) (4,)
